# %% [markdown]
# <a href="https://colab.research.google.com/github/dinukaattanayaka/ML-PCA-for-visualization-Hand-written-digits-Learn-/blob/main/ML_PCA_for_visualization_Hand_written_digits(Learn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_digits

dataset = load_digits()
images=dataset.images

print(images.shape)
# Out:
# (1797, 8, 8)

# %%
from matplotlib import pyplot as plt

plt.imshow(images[0],cmap='gray')  # images[0] kyn images array eke mulm image eka

# %%
data=dataset.data # dataset.data /  dataset.images me vidyt akara dekaka data tynw
                     # dataset.data kyn flat krpu data set eka
print(data.shape)
# Out:
# (1797, 64)

# %%
print(images[0])  # image set eke mulma image eka 8*8. array ekaka [0] kyn mulm image eka
# Out:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]

# %%
data[0]  # flat krpu image set eke mulma image eka 8*8. array ekaka [0] kyn mulm image eka
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)  # project from 64 to 2 dimensions
new_data = pca.fit_transform(data)
print(data.shape)
print(new_data.shape)
print(new_data)
# Out:
# (1797, 64)
# (1797, 2)
# [[ -1.25946645 -21.27488348]
#  [  7.9576113   20.76869896]
#  [  6.99192297   9.95598641]
#  ...
#  [ 10.8012837    6.96025223]
#  [ -4.87210009 -12.42395362]
#  [ -0.34438963  -6.36554919]]

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA

# Load the digits dataset
dataset = load_digits()

# Apply PCA to reduce to 2 components
pca = PCA(n_components=2)
new_data = pca.fit_transform(dataset.data)

# Scatter plot
plt.scatter(new_data[:, 0], new_data[:, 1], c=dataset.target, cmap='viridis', edgecolors='none')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.colorbar(label='Digit Label')
plt.title('PCA Scatter Plot of Digits Dataset')
plt.show()

# %%
print(new_data)
# Out:
# [[ -1.25946645 -21.27488348]
#  [  7.9576113   20.76869896]
#  [  6.99192297   9.95598641]
#  ...
#  [ 10.8012837    6.96025223]
#  [ -4.87210009 -12.42395362]
#  [ -0.34438963  -6.36554919]]
